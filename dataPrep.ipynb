# %%
import pandas as pd
import matplotlib.pyplot as plt
df200_299 = pd.read_json('./Desktop/scrapHomes/homeData200-299.json', orient='records')

df = df200_299.loc[:200, 'hType':'street']
df
# Out:
#            hType  rooms  sauna     price   area  year         city  \
# 0    Omakotitalo    6.0   True  348000.0  180.0  2004  Hämeenlinna
# 1     Kerrostalo    2.0   True  259000.0   60.5  1986     Helsinki
# 2     Kerrostalo    2.0   True  880000.0   89.5  1912     Helsinki
# 3     Kerrostalo    4.0   True  384000.0   85.5  2020        Espoo
# 4     Kerrostalo    2.0  False  398000.0   52.0  1960     Helsinki
# ..           ...    ...    ...       ...    ...   ...          ...
# 196     Rivitalo    4.0   True  299000.0   93.0  2022       Kuopio
# 197  Omakotitalo    3.0  False  224000.0  115.0  2009      Iisalmi
# 198   Kerrostalo    2.0   True  184000.0   59.5  2013    Kangasala
# 199   Kerrostalo    2.0   True  243000.0   49.5  2023       Kuopio
# 200  Omakotitalo    4.0   True   72000.0   78.0  1959       Kuopio
#
#               region                     street
# 0         Hattelmala                Korpimäki 4
# 1             Pasila                 Leankatu 7
# 2    Kaartinkaupunki             Kasarmikatu 34
# 3          Sepänkylä         PEURANIITTY 1 A 20
# 4               None             Kalevankatu 57
# ..               ...                        ...
# 196       Lehtoniemi          Kanavanranta 21 A
# 197        Marjahaka                Tattikuja 4
# 198       Pikonlinna  Armas Branderin katu 16 A
# 199         Keskusta       Maljalahdenkatu 17 A
# 200         Karttula         Karttulanraitti 10
#
# [201 rows x 9 columns]

# %%
cities_by_region = {
    'Ahvenanmaa': ["Mariehamn", "Jomala", "Finström", "Lemland", "Saltvik", "Hammarland", "Sund", "Eckerö", 
                   "Föglö", "Geta", "Vårdö", "Brändö", "Lumparland", "Kumlinge", "Kökar", "Sottunga"],
    'Uusimaa': ["Espoo", "Esbo", "Helsinki", "Helsingfors", "Hyvinkää", "Hyvinge", "Järvenpää", "Träskända", "Karkkila", 
                "Högfors", "Kauniainen", "Grankulla", "Kerava", "Kervo", "Kirkkonummi", "Kyrkslätt", "Lohja", "Lojo", "Mäntsälä", 
                "Nurmijärvi", "Pornainen", "Borgnäs", "Sipoo", "Sibbo", "Siuntio", "Sjundeå", "Tuusula", "Tusby", "Vantaa", "Vanda", 
                "Vihti", "Vichtis", "Lapinjärvi", "Lappträsk", "Loviisa", "Lovisa", "Hanko", "Hangö", "Ingå", "Inkoo", "Raseborg", 
                "Raasepori", "Askola", "Myrskylä", "Mörskom", "Porvoo", "Borgå", "Pukkila"],
    'Varsinais-Suomi': ["Kaarina", "S:t Karins", "Lieto", "Lundo", "Masku", "Masko", "Mynämäki", "Virmo", "Naantali", "Nådendal", 
                        "Nousiainen", "Nousis", "Paimio", "Pemar", "Raisio", "Reso", "Rusko", "Sauvo", "Sagu", "Turku", "Åbo", "Kimitoön", 
                        "Kemiönsaari", "Pargas", "Parainen", "Salo", "Somero", "Kustavi", "Gustavs", "Laitila", "Letala", "Pyhäranta", 
                        "Taivassalo", "Tövsala", "Uusikaupunki", "Nystad", "Vehmaa", "Vemo", "Aura", "Koski Tl", "Koskis", "Loimaa", "Marttila", 
                        "S:t Mårtens", "Oripää", "Pöytyä"],
    'Satakunta': ["Jämijärvi", "Kankaanpää", "Karvia", "Siikainen", "Siikais", "Eura", "Eurajoki", "Euraåminne", "Rauma", 
                "Raumo", "Säkylä", "Harjavalta", "Huittinen", "Vittis", "Kokemäki", "Kumo", "Merikarvia", "Sastmola", "Nakkila", 
                "Pomarkku", "Påmark", "Pori", "Björneborg", "Ulvila", "Ulvsby"],
    'Kanta-Häme':["Forssa", "Humppila", "Jokioinen", "Jockis", "Tammela", "Ypäjä", "Hattula", "Hämeenlinna", "Tavastehus", 
                    "Janakkala", "Hausjärvi", "Loppi", "Riihimäki"],
    'Pirkanmaa': ["Hämeenkyrö", "Tavastkyro", "Kangasala", "Kuhmoinen", "Kuhmois", "Lempäälä", "Lembois", "Nokia", "Orivesi",
                "Pirkkala", "Birkala", "Pälkäne", "Tampere", "Tammerfors", "Vesilahti", "Vesilax", "Ylöjärvi", "Ikaalinen", 
                "Ikalis", "Kihniö", "Parkano", "Juupajoki", "Mänttä-Vilppula", "Mänttä-Filpula", "Ruovesi", "Virrat", "Virdois", 
                    "Akaa", "Ackas", "Urjala", "Urdiala", "Valkeakoski", "Punkalaidun", "Pungalaitio", "Sastamala"],
    'Päijät-Häme':["Asikkala", "Hartola", "Gustav Adolfs", "Heinola", "Hollola", 
                    "Iitti", "Itis", "Kärkölä", "Lahti", "Lahtis", "Orimattila", "Padasjoki", "Sysmä"],
    'Kymenlaakso': ["Kotka", "Hamina", "Fredrikshamn", "Pyhtää", "Pyttis", "Virolahti", "Vederlax", "Miehikkälä", "Kouvola"],
    'Etelä-Karjala': ["Imatra", "Parikkala", "Rautjärvi", "Ruokolahti", "Ruokolax", "Lappeenranta", "Villmanstrand",
                    "Lemi", "Luumäki", "Savitaipale", "Taipalsaari"],
    'Etelä-Savo': ["Hirvensalmi", "Kangasniemi", "Mikkeli", "Mäntyharju", "Pertunmaa", 
                    "Puumala", "Juva", "Pieksämäki", "Enonkoski", "Rantasalmi", "Savonlinna", "Nyslott", "Sulkava"],
    'Pohjois-Savo': ["Kaavi", "Rautavaara", "Tuusniemi", "Kuopio", "Siilinjärvi", "Inner Savonia", "Rautalampi", "Suonenjoki", 
                    "Tervo", "Vesanto", "Joroinen", "Jorois", "Leppävirta", "Varkaus", "Iisalmi", "Idensalmi", "Keitele", "Kiuruvesi",
                     "Lapinlahti", "Pielavesi", "Sonkajärvi", "Vieremä"],
    'Pohjois-Karjala': ["Heinävesi", "Ilomantsi", "Ilomants", "Joensuu", "Juuka", "Juga", "Kontiolahti",
                    "Kontiolax", "Liperi", "Libelits", "Outokumpu", "Polvijärvi", "Kitee", "Kides", "Rääkkylä", "Tohmajärvi", "Lieksa", "Nurmes"],
    'Keski-Suomi': ["Joutsa", "Luhanka", "Hankasalmi", "Jyväskylä", "Laukaa", "Muurame", "Petäjävesi", "Toivakka", 
                        "Uurainen", "Jämsä", "Keuruu", "Multia", "Kannonkoski", "Karstula", "Kinnula", "Kivijärvi", 
                        "Kyyjärvi", "Pihtipudas", "Saarijärvi", "Viitasaari", "Konnevesi", "Äänekoski"],
    'Pohjanmaa': ["Korsnäs", "Laihia", "Malax","Mustasaari", "Pietarsaari", "Korsholm", "Vaasa", "Vörå", "Vöyri", "Kronoby", "Larsmo", "Pedersöre", 
                     "Jakobstad", "Nykarleby", "Kruunupyy","Kristiinankaupunki", "Kaskinen", "Kristinestad", "Närpes"],
    'Keski-Pohjanmaa': ["Halsua", "Kaustinen", "Lestijärvi", "Perho", "Toholampi", "Veteli", "Kannus", "Kokkola"],
    'Pohjois-Pohjanmaa': ["Kuusamo", "Taivalkoski", "Haapajärvi", "Kärsämäki", "Nivala",
                            "Pyhäjärvi", "Reisjärvi", "Hailuoto", "Kempele", "Liminka", "Lumijoki", "Muhos", "Oulu", 
                            "Tyrnävä", "Ii", "Pudasjärvi", "Utajärvi", "Vaala", "Pyhäjoki", "Raahe", "Siikajoki", "Haapavesi", 
                             "Pyhäntä", "Siikalatva", "Alavieska", "Kalajoki", "Merijärvi", "Oulainen", "Sievi", "Ylivieska"],
    'Lappi': ["Kemi", "Keminmaa", "Simo", "Tervola", "Tornio", "Rovaniemi", "Ranua", "Pello", "Ylitornio", "Kemijärvi", "Pelkosenniemi", "Posio", 
                "Salla", "Savukoski", "Inari", "Sodankylä", "Utsjoki", "Enontekiö", "Kittilä", "Kolari", "Muoni"],
    'Kainuu':["Kajaani", "Paltamo", "Ristijärvi", "Sotkamo", "Hyrynsalmi", "Kuhmo", "Puolanka", "Suomussalmi"],
    'Etelä-Pohjanmaa':["Alajärvi", "Evijärvi", "Lappajärvi", "Soini", "Vimpeli", "Alavus", "Kuortane", "Ähtäri", 
                       "Ilmajoki", "Isokyrö", "Kauhava", "Kurikka", "Lapua", "Seinäjoki", "Isojoki", "Karijoki", "Kauhajoki", "Teuva"],
}


city_to_region = {city: region for region, cities in cities_by_region.items() for city in cities} #{'Mariehamn': 'Ahvenanmaa','Seinäjoki': 'Etelä-Pohjanmaa',}
df['maakunta'] = df['city'].map(city_to_region)
df
# Out:
#            hType  rooms  sauna     price   area  year         city  \
# 0    Omakotitalo    6.0   True  348000.0  180.0  2004  Hämeenlinna
# 1     Kerrostalo    2.0   True  259000.0   60.5  1986     Helsinki
# 2     Kerrostalo    2.0   True  880000.0   89.5  1912     Helsinki
# 3     Kerrostalo    4.0   True  384000.0   85.5  2020        Espoo
# 4     Kerrostalo    2.0  False  398000.0   52.0  1960     Helsinki
# ..           ...    ...    ...       ...    ...   ...          ...
# 196     Rivitalo    4.0   True  299000.0   93.0  2022       Kuopio
# 197  Omakotitalo    3.0  False  224000.0  115.0  2009      Iisalmi
# 198   Kerrostalo    2.0   True  184000.0   59.5  2013    Kangasala
# 199   Kerrostalo    2.0   True  243000.0   49.5  2023       Kuopio
# 200  Omakotitalo    4.0   True   72000.0   78.0  1959       Kuopio
#
#               region                     street      maakunta
# 0         Hattelmala                Korpimäki 4    Kanta-Häme
# 1             Pasila                 Leankatu 7       Uusimaa
# 2    Kaartinkaupunki             Kasarmikatu 34       Uusimaa
# 3          Sepänkylä         PEURANIITTY 1 A 20       Uusimaa
# 4               None             Kalevankatu 57       Uusimaa
# ..               ...                        ...           ...
# 196       Lehtoniemi          Kanavanranta 21 A  Pohjois-Savo
# 197        Marjahaka                Tattikuja 4  Pohjois-Savo
# 198       Pikonlinna  Armas Branderin katu 16 A     Pirkanmaa
# 199         Keskusta       Maljalahdenkatu 17 A  Pohjois-Savo
# 200         Karttula         Karttulanraitti 10  Pohjois-Savo
#
# [201 rows x 10 columns]

# %%
city_to_region
# Out:
# {'Mariehamn': 'Ahvenanmaa',
#  'Jomala': 'Ahvenanmaa',
#  'Finström': 'Ahvenanmaa',
#  'Lemland': 'Ahvenanmaa',
#  'Saltvik': 'Ahvenanmaa',
#  'Hammarland': 'Ahvenanmaa',
#  'Sund': 'Ahvenanmaa',
#  'Eckerö': 'Ahvenanmaa',
#  'Föglö': 'Ahvenanmaa',
#  'Geta': 'Ahvenanmaa',
#  'Vårdö': 'Ahvenanmaa',
#  'Brändö': 'Ahvenanmaa',
#  'Lumparland': 'Ahvenanmaa',
#  'Kumlinge': 'Ahvenanmaa',
#  'Kökar': 'Ahvenanmaa',
#  'Sottunga': 'Ahvenanmaa',
#  'Espoo': 'Uusimaa',
#  'Esbo': 'Uusimaa',
#  'Helsinki': 'Uusimaa',
#  'Helsingfors': 'Uusimaa',
#  'Hyvinkää': 'Uusimaa',
#  'Hyvinge': 'Uusimaa',
#  'Järvenpää': 'Uusimaa',
#  'Träskända': 'Uusimaa',
#  'Karkkila': 'Uusimaa',
#  'Högfors': 'Uusimaa',
#  'Kauniainen': 'Uusimaa',
#  'Grankulla': 'Uusimaa',
#  'Kerava': 'Uusimaa',
#  'Kervo': 'Uusimaa',
#  'Kirkkonummi': 'Uusimaa',
#  'Kyrkslätt': 'Uusimaa',
#  'Lohja': 'Uusimaa',
#  'Lojo': 'Uusimaa',
#  'Mäntsälä': 'Uusimaa',
#  'Nurmijärvi': 'Uusimaa',
#  'Pornainen': 'Uusimaa',
#  'Borgnäs': 'Uusimaa',
#  'Sipoo': 'Uusimaa',
#  'Sibbo': 'Uusimaa',
#  'Siuntio': 'Uusimaa',
#  'Sjundeå': 'Uusimaa',
#  'Tuusula': 'Uusimaa',
#  'Tusby': 'Uusimaa',
#  'Vantaa': 'Uusimaa',
#  'Vanda': 'Uusimaa',
#  'Vihti': 'Uusimaa',
#  'Vichtis': 'Uusimaa',
#  'Lapinjärvi': 'Uusimaa',
#  'Lappträsk': 'Uusimaa',
#  'Loviisa': 'Uusimaa',
#  'Lovisa': 'Uusimaa',
#  'Hanko': 'Uusimaa',
#  'Hangö': 'Uusimaa',
#  'Ingå': 'Uusimaa',
#  'Inkoo': 'Uusimaa',
#  'Raseborg': 'Uusimaa',
#  'Raasepori': 'Uusimaa',
#  'Askola': 'Uusimaa',
#  'Myrskylä': 'Uusimaa',
#  'Mörskom': 'Uusimaa',
#  'Porvoo': 'Uusimaa',
#  'Borgå': 'Uusimaa',
#  'Pukkila': 'Uusimaa',
#  'Kaarina': 'Varsinais-Suomi',
#  'S:t Karins': 'Varsinais-Suomi',
#  'Lieto': 'Varsinais-Suomi',
#  'Lundo': 'Varsinais-Suomi',
#  'Masku': 'Varsinais-Suomi',
#  'Masko': 'Varsinais-Suomi',
#  'Mynämäki': 'Varsinais-Suomi',
#  'Virmo': 'Varsinais-Suomi',
#  'Naantali': 'Varsinais-Suomi',
#  'Nådendal': 'Varsinais-Suomi',
#  'Nousiainen': 'Varsinais-Suomi',
#  'Nousis': 'Varsinais-Suomi',
#  'Paimio': 'Varsinais-Suomi',
#  'Pemar': 'Varsinais-Suomi',
#  'Raisio': 'Varsinais-Suomi',
#  'Reso': 'Varsinais-Suomi',
#  'Rusko': 'Varsinais-Suomi',
#  'Sauvo': 'Varsinais-Suomi',
#  'Sagu': 'Varsinais-Suomi',
#  'Turku': 'Varsinais-Suomi',
#  'Åbo': 'Varsinais-Suomi',
#  'Kimitoön': 'Varsinais-Suomi',
#  'Kemiönsaari': 'Varsinais-Suomi',
#  'Pargas': 'Varsinais-Suomi',
#  'Parainen': 'Varsinais-Suomi',
#  'Salo': 'Varsinais-Suomi',
#  'Somero': 'Varsinais-Suomi',
#  'Kustavi': 'Varsinais-Suomi',
#  'Gustavs': 'Varsinais-Suomi',
#  'Laitila': 'Varsinais-Suomi',
#  'Letala': 'Varsinais-Suomi',
#  'Pyhäranta': 'Varsinais-Suomi',
#  'Taivassalo': 'Varsinais-Suomi',
#  'Tövsala': 'Varsinais-Suomi',
#  'Uusikaupunki': 'Varsinais-Suomi',
#  'Nystad': 'Varsinais-Suomi',
#  'Vehmaa': 'Varsinais-Suomi',
#  'Vemo': 'Varsinais-Suomi',
#  'Aura': 'Varsinais-Suomi',
#  'Koski Tl': 'Varsinais-Suomi',
#  'Koskis': 'Varsinais-Suomi',
#  'Loimaa': 'Varsinais-Suomi',
#  'Marttila': 'Varsinais-Suomi',
#  'S:t Mårtens': 'Varsinais-Suomi',
#  'Oripää': 'Varsinais-Suomi',
#  'Pöytyä': 'Varsinais-Suomi',
#  'Jämijärvi': 'Satakunta',
#  'Kankaanpää': 'Satakunta',
#  'Karvia': 'Satakunta',
#  'Siikainen': 'Satakunta',
#  'Siikais': 'Satakunta',
#  'Eura': 'Satakunta',
#  'Eurajoki': 'Satakunta',
#  'Euraåminne': 'Satakunta',
#  'Rauma': 'Satakunta',
#  'Raumo': 'Satakunta',
#  'Säkylä': 'Satakunta',
#  'Harjavalta': 'Satakunta',
#  'Huittinen': 'Satakunta',
#  'Vittis': 'Satakunta',
#  'Kokemäki': 'Satakunta',
#  'Kumo': 'Satakunta',
#  'Merikarvia': 'Satakunta',
#  'Sastmola': 'Satakunta',
#  'Nakkila': 'Satakunta',
#  'Pomarkku': 'Satakunta',
#  'Påmark': 'Satakunta',
#  'Pori': 'Satakunta',
#  'Björneborg': 'Satakunta',
#  'Ulvila': 'Satakunta',
#  'Ulvsby': 'Satakunta',
#  'Forssa': 'Kanta-Häme',
#  'Humppila': 'Kanta-Häme',
#  'Jokioinen': 'Kanta-Häme',
#  'Jockis': 'Kanta-Häme',
#  'Tammela': 'Kanta-Häme',
#  'Ypäjä': 'Kanta-Häme',
#  'Hattula': 'Kanta-Häme',
#  'Hämeenlinna': 'Kanta-Häme',
#  'Tavastehus': 'Kanta-Häme',
#  'Janakkala': 'Kanta-Häme',
#  'Hausjärvi': 'Kanta-Häme',
#  'Loppi': 'Kanta-Häme',
#  'Riihimäki': 'Kanta-Häme',
#  'Hämeenkyrö': 'Pirkanmaa',
#  'Tavastkyro': 'Pirkanmaa',
#  'Kangasala': 'Pirkanmaa',
#  'Kuhmoinen': 'Pirkanmaa',
#  'Kuhmois': 'Pirkanmaa',
#  'Lempäälä': 'Pirkanmaa',
#  'Lembois': 'Pirkanmaa',
#  'Nokia': 'Pirkanmaa',
#  'Orivesi': 'Pirkanmaa',
#  'Pirkkala': 'Pirkanmaa',
#  'Birkala': 'Pirkanmaa',
#  'Pälkäne': 'Pirkanmaa',
#  'Tampere': 'Pirkanmaa',
#  'Tammerfors': 'Pirkanmaa',
#  'Vesilahti': 'Pirkanmaa',
#  'Vesilax': 'Pirkanmaa',
#  'Ylöjärvi': 'Pirkanmaa',
#  'Ikaalinen': 'Pirkanmaa',
#  'Ikalis': 'Pirkanmaa',
#  'Kihniö': 'Pirkanmaa',
#  'Parkano': 'Pirkanmaa',
#  'Juupajoki': 'Pirkanmaa',
#  'Mänttä-Vilppula': 'Pirkanmaa',
#  'Mänttä-Filpula': 'Pirkanmaa',
#  'Ruovesi': 'Pirkanmaa',
#  'Virrat': 'Pirkanmaa',
#  'Virdois': 'Pirkanmaa',
#  'Akaa': 'Pirkanmaa',
#  'Ackas': 'Pirkanmaa',
#  'Urjala': 'Pirkanmaa',
#  'Urdiala': 'Pirkanmaa',
#  'Valkeakoski': 'Pirkanmaa',
#  'Punkalaidun': 'Pirkanmaa',
#  'Pungalaitio': 'Pirkanmaa',
#  'Sastamala': 'Pirkanmaa',
#  'Asikkala': 'Päijät-Häme',
#  'Hartola': 'Päijät-Häme',
#  'Gustav Adolfs': 'Päijät-Häme',
#  'Heinola': 'Päijät-Häme',
#  'Hollola': 'Päijät-Häme',
#  'Iitti': 'Päijät-Häme',
#  'Itis': 'Päijät-Häme',
#  'Kärkölä': 'Päijät-Häme',
#  'Lahti': 'Päijät-Häme',
#  'Lahtis': 'Päijät-Häme',
#  'Orimattila': 'Päijät-Häme',
#  'Padasjoki': 'Päijät-Häme',
#  'Sysmä': 'Päijät-Häme',
#  'Kotka': 'Kymenlaakso',
#  'Hamina': 'Kymenlaakso',
#  'Fredrikshamn': 'Kymenlaakso',
#  'Pyhtää': 'Kymenlaakso',
#  'Pyttis': 'Kymenlaakso',
#  'Virolahti': 'Kymenlaakso',
#  'Vederlax': 'Kymenlaakso',
#  'Miehikkälä': 'Kymenlaakso',
#  'Kouvola': 'Kymenlaakso',
#  'Imatra': 'Etelä-Karjala',
#  'Parikkala': 'Etelä-Karjala',
#  'Rautjärvi': 'Etelä-Karjala',
#  'Ruokolahti': 'Etelä-Karjala',
#  'Ruokolax': 'Etelä-Karjala',
#  'Lappeenranta': 'Etelä-Karjala',
#  'Villmanstrand': 'Etelä-Karjala',
#  'Lemi': 'Etelä-Karjala',
#  'Luumäki': 'Etelä-Karjala',
#  'Savitaipale': 'Etelä-Karjala',
#  'Taipalsaari': 'Etelä-Karjala',
#  'Hirvensalmi': 'Etelä-Savo',
#  'Kangasniemi': 'Etelä-Savo',
#  'Mikkeli': 'Etelä-Savo',
#  'Mäntyharju': 'Etelä-Savo',
#  'Pertunmaa': 'Etelä-Savo',
#  'Puumala': 'Etelä-Savo',
#  'Juva': 'Etelä-Savo',
#  'Pieksämäki': 'Etelä-Savo',
#  'Enonkoski': 'Etelä-Savo',
#  'Rantasalmi': 'Etelä-Savo',
#  'Savonlinna': 'Etelä-Savo',
#  'Nyslott': 'Etelä-Savo',
#  'Sulkava': 'Etelä-Savo',
#  'Kaavi': 'Pohjois-Savo',
#  'Rautavaara': 'Pohjois-Savo',
#  'Tuusniemi': 'Pohjois-Savo',
#  'Kuopio': 'Pohjois-Savo',
#  'Siilinjärvi': 'Pohjois-Savo',
#  'Inner Savonia': 'Pohjois-Savo',
#  'Rautalampi': 'Pohjois-Savo',
#  'Suonenjoki': 'Pohjois-Savo',
#  'Tervo': 'Pohjois-Savo',
#  'Vesanto': 'Pohjois-Savo',
#  'Joroinen': 'Pohjois-Savo',
#  'Jorois': 'Pohjois-Savo',
#  'Leppävirta': 'Pohjois-Savo',
#  'Varkaus': 'Pohjois-Savo',
#  'Iisalmi': 'Pohjois-Savo',
#  'Idensalmi': 'Pohjois-Savo',
#  'Keitele': 'Pohjois-Savo',
#  'Kiuruvesi': 'Pohjois-Savo',
#  'Lapinlahti': 'Pohjois-Savo',
#  'Pielavesi': 'Pohjois-Savo',
#  'Sonkajärvi': 'Pohjois-Savo',
#  'Vieremä': 'Pohjois-Savo',
#  'Heinävesi': 'Pohjois-Karjala',
#  'Ilomantsi': 'Pohjois-Karjala',
#  'Ilomants': 'Pohjois-Karjala',
#  'Joensuu': 'Pohjois-Karjala',
#  'Juuka': 'Pohjois-Karjala',
#  'Juga': 'Pohjois-Karjala',
#  'Kontiolahti': 'Pohjois-Karjala',
#  'Kontiolax': 'Pohjois-Karjala',
#  'Liperi': 'Pohjois-Karjala',
#  'Libelits': 'Pohjois-Karjala',
#  'Outokumpu': 'Pohjois-Karjala',
#  'Polvijärvi': 'Pohjois-Karjala',
#  'Kitee': 'Pohjois-Karjala',
#  'Kides': 'Pohjois-Karjala',
#  'Rääkkylä': 'Pohjois-Karjala',
#  'Tohmajärvi': 'Pohjois-Karjala',
#  'Lieksa': 'Pohjois-Karjala',
#  'Nurmes': 'Pohjois-Karjala',
#  'Joutsa': 'Keski-Suomi',
#  'Luhanka': 'Keski-Suomi',
#  'Hankasalmi': 'Keski-Suomi',
#  'Jyväskylä': 'Keski-Suomi',
#  'Laukaa': 'Keski-Suomi',
#  'Muurame': 'Keski-Suomi',
#  'Petäjävesi': 'Keski-Suomi',
#  'Toivakka': 'Keski-Suomi',
#  'Uurainen': 'Keski-Suomi',
#  'Jämsä': 'Keski-Suomi',
#  'Keuruu': 'Keski-Suomi',
#  'Multia': 'Keski-Suomi',
#  'Kannonkoski': 'Keski-Suomi',
#  'Karstula': 'Keski-Suomi',
#  'Kinnula': 'Keski-Suomi',
#  'Kivijärvi': 'Keski-Suomi',
#  'Kyyjärvi': 'Keski-Suomi',
#  'Pihtipudas': 'Keski-Suomi',
#  'Saarijärvi': 'Keski-Suomi',
#  'Viitasaari': 'Keski-Suomi',
#  'Konnevesi': 'Keski-Suomi',
#  'Äänekoski': 'Keski-Suomi',
#  'Korsnäs': 'Pohjanmaa',
#  'Laihia': 'Pohjanmaa',
#  'Malax': 'Pohjanmaa',
#  'Mustasaari': 'Pohjanmaa',
#  'Pietarsaari': 'Pohjanmaa',
#  'Korsholm': 'Pohjanmaa',
#  'Vaasa': 'Pohjanmaa',
#  'Vörå': 'Pohjanmaa',
#  'Vöyri': 'Pohjanmaa',
#  'Kronoby': 'Pohjanmaa',
#  'Larsmo': 'Pohjanmaa',
#  'Pedersöre': 'Pohjanmaa',
#  'Jakobstad': 'Pohjanmaa',
#  'Nykarleby': 'Pohjanmaa',
#  'Kruunupyy': 'Pohjanmaa',
#  'Kristiinankaupunki': 'Pohjanmaa',
#  'Kaskinen': 'Pohjanmaa',
#  'Kristinestad': 'Pohjanmaa',
#  'Närpes': 'Pohjanmaa',
#  'Halsua': 'Keski-Pohjanmaa',
#  'Kaustinen': 'Keski-Pohjanmaa',
#  'Lestijärvi': 'Keski-Pohjanmaa',
#  'Perho': 'Keski-Pohjanmaa',
#  'Toholampi': 'Keski-Pohjanmaa',
#  'Veteli': 'Keski-Pohjanmaa',
#  'Kannus': 'Keski-Pohjanmaa',
#  'Kokkola': 'Keski-Pohjanmaa',
#  'Kuusamo': 'Pohjois-Pohjanmaa',
#  'Taivalkoski': 'Pohjois-Pohjanmaa',
#  'Haapajärvi': 'Pohjois-Pohjanmaa',
#  'Kärsämäki': 'Pohjois-Pohjanmaa',
#  'Nivala': 'Pohjois-Pohjanmaa',
#  'Pyhäjärvi': 'Pohjois-Pohjanmaa',
#  'Reisjärvi': 'Pohjois-Pohjanmaa',
#  'Hailuoto': 'Pohjois-Pohjanmaa',
#  'Kempele': 'Pohjois-Pohjanmaa',
#  'Liminka': 'Pohjois-Pohjanmaa',
#  'Lumijoki': 'Pohjois-Pohjanmaa',
#  'Muhos': 'Pohjois-Pohjanmaa',
#  'Oulu': 'Pohjois-Pohjanmaa',
#  'Tyrnävä': 'Pohjois-Pohjanmaa',
#  'Ii': 'Pohjois-Pohjanmaa',
#  'Pudasjärvi': 'Pohjois-Pohjanmaa',
#  'Utajärvi': 'Pohjois-Pohjanmaa',
#  'Vaala': 'Pohjois-Pohjanmaa',
#  'Pyhäjoki': 'Pohjois-Pohjanmaa',
#  'Raahe': 'Pohjois-Pohjanmaa',
#  'Siikajoki': 'Pohjois-Pohjanmaa',
#  'Haapavesi': 'Pohjois-Pohjanmaa',
#  'Pyhäntä': 'Pohjois-Pohjanmaa',
#  'Siikalatva': 'Pohjois-Pohjanmaa',
#  'Alavieska': 'Pohjois-Pohjanmaa',
#  'Kalajoki': 'Pohjois-Pohjanmaa',
#  'Merijärvi': 'Pohjois-Pohjanmaa',
#  'Oulainen': 'Pohjois-Pohjanmaa',
#  'Sievi': 'Pohjois-Pohjanmaa',
#  'Ylivieska': 'Pohjois-Pohjanmaa',
#  'Kemi': 'Lappi',
#  'Keminmaa': 'Lappi',
#  'Simo': 'Lappi',
#  'Tervola': 'Lappi',
#  'Tornio': 'Lappi',
#  'Rovaniemi': 'Lappi',
#  'Ranua': 'Lappi',
#  'Pello': 'Lappi',
#  'Ylitornio': 'Lappi',
#  'Kemijärvi': 'Lappi',
#  'Pelkosenniemi': 'Lappi',
#  'Posio': 'Lappi',
#  'Salla': 'Lappi',
#  'Savukoski': 'Lappi',
#  'Inari': 'Lappi',
#  'Sodankylä': 'Lappi',
#  'Utsjoki': 'Lappi',
#  'Enontekiö': 'Lappi',
#  'Kittilä': 'Lappi',
#  'Kolari': 'Lappi',
#  'Muoni': 'Lappi',
#  'Kajaani': 'Kainuu',
#  'Paltamo': 'Kainuu',
#  'Ristijärvi': 'Kainuu',
#  'Sotkamo': 'Kainuu',
#  'Hyrynsalmi': 'Kainuu',
#  'Kuhmo': 'Kainuu',
#  'Puolanka': 'Kainuu',
#  'Suomussalmi': 'Kainuu',
#  'Alajärvi': 'Etelä-Pohjanmaa',
#  'Evijärvi': 'Etelä-Pohjanmaa',
#  'Lappajärvi': 'Etelä-Pohjanmaa',
#  'Soini': 'Etelä-Pohjanmaa',
#  'Vimpeli': 'Etelä-Pohjanmaa',
#  'Alavus': 'Etelä-Pohjanmaa',
#  'Kuortane': 'Etelä-Pohjanmaa',
#  'Ähtäri': 'Etelä-Pohjanmaa',
#  'Ilmajoki': 'Etelä-Pohjanmaa',
#  'Isokyrö': 'Etelä-Pohjanmaa',
#  'Kauhava': 'Etelä-Pohjanmaa',
#  'Kurikka': 'Etelä-Pohjanmaa',
#  'Lapua': 'Etelä-Pohjanmaa',
#  'Seinäjoki': 'Etelä-Pohjanmaa',
#  'Isojoki': 'Etelä-Pohjanmaa',
#  'Karijoki': 'Etelä-Pohjanmaa',
#  'Kauhajoki': 'Etelä-Pohjanmaa',
#  'Teuva': 'Etelä-Pohjanmaa'}

# %%
df300_399 = pd.read_json('./Desktop/scrapHomes/homeData300-399.json', orient='records')
df300_399
# Out:
# Index(['hType', 'rooms', 'sauna', 'price', 'area', 'year', 'city', 'region',
#        'street', 'seller'],
#       dtype='object')

# %%
df2_199 = pd.read_csv('finHousing2-199.csv')
df2_199
# Out:
#            hType  rooms  sauna     price   area  year       city       region  \
# 0       Rivitalo    4.0   True  249000.0   87.5  2025    Kempele          NaN
# 1     Kerrostalo    3.0  False  119000.0   77.5  1954      Rauma          Ota
# 2       Paritalo    4.0   True  464000.0  108.5  2022   Lempäälä      Annisto
# 3     Kerrostalo    4.0  False   59000.0   92.5  1971    Kouvola          NaN
# 4     Kerrostalo    3.0   True   49000.0   80.0  1978  Jyväskylä        Sulku
# ...          ...    ...    ...       ...    ...   ...        ...          ...
# 5935  Kerrostalo    3.0   True   30000.0   80.0  1996     Kerava      Sampola
# 5936  Kerrostalo    4.0  False  507000.0   78.0  1939   Helsinki   Taka-Töölö
# 5937  Kerrostalo    3.0  False   37000.0   71.0  2025  Kangasala  Lamminrahka
# 5938    Rivitalo    3.0   True  225000.0   80.0  2025    Kempele      Tähkälä
# 5939    Rivitalo    4.0   True  249000.0   87.5  2025    Kempele          NaN
#
#                     street                           seller
# 0               Akana 2 A3                       Puroila Oy
# 1        Syväraumankatu 14                        Rauma LKV
# 2         Leppikaijantie 2  Herrainmäki | Niittymäki LKV Oy
# 3        Porvarinpolku 1 a      RE/MAX Noste | Noste Oy LKV
# 4          Kaakonsiipi 8 D           Jyväskylän VendoLKV Oy
# ...                    ...                              ...
# 5935        Sampolankatu 5                              NaN
# 5936     Humalistonkatu 15                              NaN
# 5937  Mossin puistokatu 26                              NaN
# 5938            Akana 2 B5                              NaN
# 5939            Akana 2 A3                              NaN
#
# [5940 rows x 10 columns]

# %%
df2_399 = pd.concat([df2_199, df200_299, df300_399], axis=0, ignore_index=True)

# %%
subset_columns = [col for col in df2_399.columns if col != 'seller']
df2_399.duplicated(subset = subset_columns).value_counts()
# Out:
# False    11799
# True       111
# Name: count, dtype: int64

# %%
df2_399.drop_duplicates(subset = subset_columns, keep='first', inplace = True)
# Out:
# False    11799
# Name: count, dtype: int64

# %%
df2_399.duplicated().value_counts()
# Out:
# False    11799
# Name: count, dtype: int64

# %%
#df2_399.to_csv('finHouse2-399.csv', index=False )  ## to save as csv file
